# %%
from citipy import citipy 
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7ea6b6fc43a70611a51955bf5b262681

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7ea6b6fc43a70611a51955bf5b262681&q=Boston

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city_data = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | salihorsk
# Processing Record 3 of Set 1 | rudnogorsk
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | kelvington
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | tombouctou
# Processing Record 19 of Set 1 | ratnagiri
# Processing Record 20 of Set 1 | artyom
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | olga
# Processing Record 24 of Set 1 | imbituba
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | la ronge
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | matara
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | rudbar
# Processing Record 39 of Set 1 | wanning
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | komsomolskiy
# Processing Record 42 of Set 1 | shache
# Processing Record 43 of Set 1 | kawalu
# Processing Record 44 of Set 1 | naze
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | bathsheba
# Processing Record 47 of Set 1 | amahai
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | bilma
# Processing Record 2 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 2 | abnub
# Processing Record 4 of Set 2 | stranda
# Processing Record 5 of Set 2 | tsiroanomandidy
# Processing Record 6 of Set 2 | praia da vitoria
# Processing Record 7 of Set 2 | dudinka
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | constitucion
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | colombo
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | sassandra
# Processing Record 16 of Set 2 | dingle
# Processing Record 17 of Set 2 | mana
# Processing Record 18 of Set 2 | hervey bay
# Processing Record 19 of Set 2 | clyde river
# Processing Record 20 of Set 2 | mecca
# Processing Record 21 of Set 2 | lompoc
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | tres lagoas
# Processing Record 24 of Set 2 | lesnoy
# Processing Record 25 of Set 2 | half moon bay
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | chumikan
# Processing Record 29 of Set 2 | coihaique
# Processing Record 30 of Set 2 | crawfordsville
# Processing Record 31 of Set 2 | bafq
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | noumea
# Processing Record 34 of Set 2 | hamilton
# Processing Record 35 of Set 2 | cap malheureux
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | beausoleil
# Processing Record 39 of Set 2 | amstetten
# Processing Record 40 of Set 2 | alyangula
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | xifeng
# Processing Record 43 of Set 2 | fuxin
# Processing Record 44 of Set 2 | makakilo city
# Processing Record 45 of Set 2 | raudeberg
# Processing Record 46 of Set 2 | lindsay
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | eregli
# Processing Record 49 of Set 2 | saurimo
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | klyuchi
# Processing Record 3 of Set 3 | puerto madryn
# Processing Record 4 of Set 3 | sao joao da barra
# Processing Record 5 of Set 3 | ina
# Processing Record 6 of Set 3 | broome
# Processing Record 7 of Set 3 | manzanillo
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | hermanus
# Processing Record 11 of Set 3 | batagay-alyta
# Processing Record 12 of Set 3 | oxford
# Processing Record 13 of Set 3 | portland
# Processing Record 14 of Set 3 | sur
# Processing Record 15 of Set 3 | popondetta
# Processing Record 16 of Set 3 | broken hill
# Processing Record 17 of Set 3 | pacific grove
# Processing Record 18 of Set 3 | axim
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | palmer
# Processing Record 21 of Set 3 | noormarkku
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | dogondoutchi
# Processing Record 24 of Set 3 | barrow
# Processing Record 25 of Set 3 | ketchikan
# Processing Record 26 of Set 3 | neyshabur
# Processing Record 27 of Set 3 | porto novo
# Processing Record 28 of Set 3 | mananjary
# Processing Record 29 of Set 3 | buckie
# Processing Record 30 of Set 3 | nouadhibou
# Processing Record 31 of Set 3 | cascais
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | santa rosa
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | kazanka
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | torbay
# Processing Record 38 of Set 3 | deputatskiy
# Processing Record 39 of Set 3 | champerico
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | ostrovnoy
# Processing Record 42 of Set 3 | oyama
# Processing Record 43 of Set 3 | guerrero negro
# Processing Record 44 of Set 3 | nador
# Processing Record 45 of Set 3 | ugento
# Processing Record 46 of Set 3 | emmett
# Processing Record 47 of Set 3 | jamestown
# Processing Record 48 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 3 | birjand
# Processing Record 50 of Set 3 | green river
# Processing Record 1 of Set 4 | tiksi
# Processing Record 2 of Set 4 | khatanga
# Processing Record 3 of Set 4 | malanje
# Processing Record 4 of Set 4 | sinegorye
# Processing Record 5 of Set 4 | pangody
# Processing Record 6 of Set 4 | haines junction
# Processing Record 7 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 4 | andenes
# Processing Record 9 of Set 4 | port alfred
# Processing Record 10 of Set 4 | dindori
# Processing Record 11 of Set 4 | timmins
# Processing Record 12 of Set 4 | sao filipe
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 4 | chute-aux-outardes
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | mayo
# Processing Record 18 of Set 4 | villa juarez
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | atuona
# Processing Record 21 of Set 4 | curitibanos
# Processing Record 22 of Set 4 | saint anthony
# Processing Record 23 of Set 4 | north bend
# Processing Record 24 of Set 4 | ciudad bolivar
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | upernavik
# Processing Record 31 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 4 | saint-georges
# Processing Record 33 of Set 4 | atar
# Processing Record 34 of Set 4 | svetlogorsk
# Processing Record 35 of Set 4 | coos bay
# Processing Record 36 of Set 4 | ponta do sol
# Processing Record 37 of Set 4 | tilichiki
# Processing Record 38 of Set 4 | duyun
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | college
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | deyang
# Processing Record 43 of Set 4 | smolenka
# Processing Record 44 of Set 4 | goderich
# Processing Record 45 of Set 4 | mangrol
# Processing Record 46 of Set 4 | kimbe
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | irbit
# Processing Record 49 of Set 4 | bongaree
# Processing Record 50 of Set 4 | maloy
# Processing Record 1 of Set 5 | gunjur
# Processing Record 2 of Set 5 | lavrentiya
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | mount pleasant
# Processing Record 6 of Set 5 | tlahualilo
# City not found. Skipping...
# Processing Record 7 of Set 5 | kavieng
# Processing Record 8 of Set 5 | tuy hoa
# Processing Record 9 of Set 5 | hasaki
# Processing Record 10 of Set 5 | el prat de llobregat
# Processing Record 11 of Set 5 | mawlaik
# Processing Record 12 of Set 5 | seminole
# Processing Record 13 of Set 5 | hoshcha
# Processing Record 14 of Set 5 | nanpiao
# Processing Record 15 of Set 5 | riyadh
# Processing Record 16 of Set 5 | kedougou
# Processing Record 17 of Set 5 | hermosillo
# Processing Record 18 of Set 5 | tautira
# Processing Record 19 of Set 5 | roald
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | flin flon
# Processing Record 22 of Set 5 | havre-saint-pierre
# Processing Record 23 of Set 5 | ardahan
# Processing Record 24 of Set 5 | grand gaube
# Processing Record 25 of Set 5 | hanna
# Processing Record 26 of Set 5 | ami
# Processing Record 27 of Set 5 | ibb
# Processing Record 28 of Set 5 | jacareacanga
# Processing Record 29 of Set 5 | monroe
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | kununurra
# Processing Record 32 of Set 5 | bonthe
# Processing Record 33 of Set 5 | nome
# Processing Record 34 of Set 5 | te anau
# Processing Record 35 of Set 5 | rock springs
# Processing Record 36 of Set 5 | kushima
# Processing Record 37 of Set 5 | aykhal
# Processing Record 38 of Set 5 | naryan-mar
# Processing Record 39 of Set 5 | bethel
# Processing Record 40 of Set 5 | hovd
# Processing Record 41 of Set 5 | dolores
# Processing Record 42 of Set 5 | lagoa
# Processing Record 43 of Set 5 | acapulco
# Processing Record 44 of Set 5 | santa cruz de tenerife
# Processing Record 45 of Set 5 | marystown
# Processing Record 46 of Set 5 | ambilobe
# Processing Record 47 of Set 5 | mar del plata
# Processing Record 48 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 5 | cayenne
# Processing Record 50 of Set 5 | vuktyl
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | isla vista
# Processing Record 3 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 6 | marshall
# Processing Record 5 of Set 6 | sisimiut
# Processing Record 6 of Set 6 | ust-nera
# Processing Record 7 of Set 6 | sharjah
# Processing Record 8 of Set 6 | dunedin
# Processing Record 9 of Set 6 | kavaratti
# Processing Record 10 of Set 6 | mae ramat
# Processing Record 11 of Set 6 | sabha
# Processing Record 12 of Set 6 | praia
# Processing Record 13 of Set 6 | gerash
# Processing Record 14 of Set 6 | port macquarie
# Processing Record 15 of Set 6 | labrea
# Processing Record 16 of Set 6 | thinadhoo
# Processing Record 17 of Set 6 | saint-joseph
# Processing Record 18 of Set 6 | bogorodskoye
# Processing Record 19 of Set 6 | barahona
# Processing Record 20 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 21 of Set 6 | yermakovskoye
# Processing Record 22 of Set 6 | acari
# Processing Record 23 of Set 6 | ban dung
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | chuy
# Processing Record 26 of Set 6 | dali
# Processing Record 27 of Set 6 | evensk
# Processing Record 28 of Set 6 | honiara
# Processing Record 29 of Set 6 | luderitz
# Processing Record 30 of Set 6 | fernley
# Processing Record 31 of Set 6 | hemsedal
# Processing Record 32 of Set 6 | lillooet
# Processing Record 33 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 6 | marawi
# Processing Record 35 of Set 6 | korem
# Processing Record 36 of Set 6 | freire
# Processing Record 37 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 38 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 39 of Set 6 | gallup
# Processing Record 40 of Set 6 | adrar
# Processing Record 41 of Set 6 | nijar
# Processing Record 42 of Set 6 | pochutla
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | bembereke
# Processing Record 45 of Set 6 | san quintin
# Processing Record 46 of Set 6 | arrigorriaga
# Processing Record 47 of Set 6 | port hardy
# Processing Record 48 of Set 6 | anadyr
# Processing Record 49 of Set 6 | biaora
# Processing Record 50 of Set 6 | ferme-neuve
# Processing Record 1 of Set 7 | westport
# Processing Record 2 of Set 7 | villa carlos paz
# Processing Record 3 of Set 7 | russell
# Processing Record 4 of Set 7 | faridabad
# Processing Record 5 of Set 7 | gaoua
# Processing Record 6 of Set 7 | omboue
# Processing Record 7 of Set 7 | butaritari
# Processing Record 8 of Set 7 | siva
# Processing Record 9 of Set 7 | san isidro
# Processing Record 10 of Set 7 | faya
# Processing Record 11 of Set 7 | uvarovo
# Processing Record 12 of Set 7 | vila franca do campo
# Processing Record 13 of Set 7 | phitsanulok
# Processing Record 14 of Set 7 | oussouye
# Processing Record 15 of Set 7 | maridi
# Processing Record 16 of Set 7 | sitka
# Processing Record 17 of Set 7 | znamenskoye
# Processing Record 18 of Set 7 | cody
# Processing Record 19 of Set 7 | kardailovo
# Processing Record 20 of Set 7 | hobyo
# Processing Record 21 of Set 7 | uyemskiy
# Processing Record 22 of Set 7 | bengkulu
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | bulungu
# Processing Record 25 of Set 7 | progreso
# Processing Record 26 of Set 7 | carutapera
# Processing Record 27 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 7 | madang
# Processing Record 29 of Set 7 | bongandanga
# Processing Record 30 of Set 7 | isangel
# Processing Record 31 of Set 7 | coari
# Processing Record 32 of Set 7 | east london
# Processing Record 33 of Set 7 | marzuq
# Processing Record 34 of Set 7 | cuamba
# Processing Record 35 of Set 7 | sao miguel do araguaia
# Processing Record 36 of Set 7 | labuhan
# Processing Record 37 of Set 7 | gannan
# Processing Record 38 of Set 7 | paita
# Processing Record 39 of Set 7 | lons-le-saunier
# Processing Record 40 of Set 7 | marau
# Processing Record 41 of Set 7 | wasilla
# Processing Record 42 of Set 7 | maniitsoq
# Processing Record 43 of Set 7 | egvekinot
# Processing Record 44 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 7 | mingguang
# Processing Record 46 of Set 7 | bingen
# Processing Record 47 of Set 7 | ixtapa
# Processing Record 48 of Set 7 | springbok
# Processing Record 49 of Set 7 | bonavista
# Processing Record 50 of Set 7 | mount darwin
# Processing Record 1 of Set 8 | bud
# Processing Record 2 of Set 8 | kawardha
# Processing Record 3 of Set 8 | svetlyy
# Processing Record 4 of Set 8 | lastoursville
# Processing Record 5 of Set 8 | warragul
# Processing Record 6 of Set 8 | sakaraha
# Processing Record 7 of Set 8 | tuktoyaktuk
# Processing Record 8 of Set 8 | taoudenni
# Processing Record 9 of Set 8 | gillette
# Processing Record 10 of Set 8 | vysokogornyy
# Processing Record 11 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 8 | vardo
# Processing Record 13 of Set 8 | tingrela
# City not found. Skipping...
# Processing Record 14 of Set 8 | mahanoro
# Processing Record 15 of Set 8 | fukue
# Processing Record 16 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 8 | karpogory
# Processing Record 18 of Set 8 | mahibadhoo
# Processing Record 19 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 20 of Set 8 | qasigiannguit
# Processing Record 21 of Set 8 | basco
# Processing Record 22 of Set 8 | alofi
# Processing Record 23 of Set 8 | vanavara
# Processing Record 24 of Set 8 | umm lajj
# Processing Record 25 of Set 8 | pedasi
# Processing Record 26 of Set 8 | batemans bay
# Processing Record 27 of Set 8 | awjilah
# Processing Record 28 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 29 of Set 8 | jiuquan
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | ahipara
# Processing Record 32 of Set 8 | yerbogachen
# Processing Record 33 of Set 8 | paciran
# Processing Record 34 of Set 8 | at-bashi
# Processing Record 35 of Set 8 | constantine
# Processing Record 36 of Set 8 | bowen
# Processing Record 37 of Set 8 | santa maria
# Processing Record 38 of Set 8 | la cruz
# Processing Record 39 of Set 8 | pital
# Processing Record 40 of Set 8 | warah
# Processing Record 41 of Set 8 | tatawin
# Processing Record 42 of Set 8 | tyler
# Processing Record 43 of Set 8 | bitung
# Processing Record 44 of Set 8 | angelholm
# City not found. Skipping...
# Processing Record 45 of Set 8 | ugoofaaru
# Processing Record 46 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 8 | altay
# Processing Record 48 of Set 8 | san juan del sur
# Processing Record 49 of Set 8 | presov
# Processing Record 50 of Set 8 | pirapo
# Processing Record 1 of Set 9 | soluno-dmitriyevskoye
# Processing Record 2 of Set 9 | pontianak
# Processing Record 3 of Set 9 | skjervoy
# Processing Record 4 of Set 9 | shakiso
# Processing Record 5 of Set 9 | san rafael
# Processing Record 6 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 9 | yuksekova
# Processing Record 8 of Set 9 | fort nelson
# Processing Record 9 of Set 9 | katsuura
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | fortuna foothills
# Processing Record 12 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 9 | sinnamary
# Processing Record 14 of Set 9 | lincoln
# Processing Record 15 of Set 9 | yuanping
# Processing Record 16 of Set 9 | bumba
# Processing Record 17 of Set 9 | kulhudhuffushi
# Processing Record 18 of Set 9 | istok
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | teocaltiche
# Processing Record 21 of Set 9 | bam
# Processing Record 22 of Set 9 | vanimo
# Processing Record 23 of Set 9 | ferrol
# Processing Record 24 of Set 9 | dawei
# Processing Record 25 of Set 9 | kano
# Processing Record 26 of Set 9 | taian
# Processing Record 27 of Set 9 | krasnovka
# Processing Record 28 of Set 9 | oksfjord
# Processing Record 29 of Set 9 | jaora
# Processing Record 30 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 9 | bemidji
# Processing Record 32 of Set 9 | gizo
# Processing Record 33 of Set 9 | vilhena
# Processing Record 34 of Set 9 | lekoni
# Processing Record 35 of Set 9 | katobu
# Processing Record 36 of Set 9 | henties bay
# Processing Record 37 of Set 9 | ustyuzhna
# Processing Record 38 of Set 9 | siniscola
# Processing Record 39 of Set 9 | kilindoni
# Processing Record 40 of Set 9 | timra
# Processing Record 41 of Set 9 | phuntsholing
# Processing Record 42 of Set 9 | monterey
# Processing Record 43 of Set 9 | coahuayana
# Processing Record 44 of Set 9 | vestmannaeyjar
# Processing Record 45 of Set 9 | hofn
# Processing Record 46 of Set 9 | lake charles
# Processing Record 47 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 9 | severo-kurilsk
# Processing Record 49 of Set 9 | muros
# Processing Record 50 of Set 9 | antofagasta
# Processing Record 1 of Set 10 | susanville
# Processing Record 2 of Set 10 | boundiali
# Processing Record 3 of Set 10 | nyurba
# Processing Record 4 of Set 10 | masaki
# Processing Record 5 of Set 10 | tessalit
# Processing Record 6 of Set 10 | chicama
# Processing Record 7 of Set 10 | belluno
# Processing Record 8 of Set 10 | arkhara
# Processing Record 9 of Set 10 | fowa
# Processing Record 10 of Set 10 | bacolod
# Processing Record 11 of Set 10 | ruthin
# Processing Record 12 of Set 10 | seoul
# Processing Record 13 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 14 of Set 10 | puerto escondido
# Processing Record 15 of Set 10 | shimanovsk
# Processing Record 16 of Set 10 | lata
# Processing Record 17 of Set 10 | camacha
# Processing Record 18 of Set 10 | pangnirtung
# Processing Record 19 of Set 10 | trincomalee
# Processing Record 20 of Set 10 | ilulissat
# Processing Record 21 of Set 10 | leeton
# Processing Record 22 of Set 10 | waipawa
# Processing Record 23 of Set 10 | huarmey
# Processing Record 24 of Set 10 | chulym
# Processing Record 25 of Set 10 | yagodnoye
# Processing Record 26 of Set 10 | domoni
# Processing Record 27 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 28 of Set 10 | roma
# Processing Record 29 of Set 10 | kattivakkam
# Processing Record 30 of Set 10 | satana
# Processing Record 31 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 10 | milkovo
# Processing Record 34 of Set 10 | cabo san lucas
# Processing Record 35 of Set 10 | folldal
# Processing Record 36 of Set 10 | x-can
# City not found. Skipping...
# Processing Record 37 of Set 10 | vernon
# Processing Record 38 of Set 10 | albanel
# Processing Record 39 of Set 10 | houma
# Processing Record 40 of Set 10 | dunmore town
# Processing Record 41 of Set 10 | coquimbo
# Processing Record 42 of Set 10 | erzin
# Processing Record 43 of Set 10 | helong
# Processing Record 44 of Set 10 | litovko
# Processing Record 45 of Set 10 | talcahuano
# Processing Record 46 of Set 10 | sioux lookout
# Processing Record 47 of Set 10 | jacksonville
# Processing Record 48 of Set 10 | montepuez
# Processing Record 49 of Set 10 | abonnema
# Processing Record 50 of Set 10 | magdagachi
# Processing Record 1 of Set 11 | praya
# Processing Record 2 of Set 11 | novoagansk
# Processing Record 3 of Set 11 | bingol
# Processing Record 4 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 11 | kaitangata
# Processing Record 6 of Set 11 | yulara
# Processing Record 7 of Set 11 | guanare
# Processing Record 8 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 11 | ryotsu
# Processing Record 10 of Set 11 | sari
# Processing Record 11 of Set 11 | yucaipa
# Processing Record 12 of Set 11 | mandalgovi
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | vao
# Processing Record 15 of Set 11 | huron
# Processing Record 16 of Set 11 | candido mendes
# Processing Record 17 of Set 11 | pijijiapan
# Processing Record 18 of Set 11 | porbandar
# Processing Record 19 of Set 11 | del rio
# Processing Record 20 of Set 11 | klaksvik
# Processing Record 21 of Set 11 | nizhnevartovsk
# Processing Record 22 of Set 11 | culpeper
# Processing Record 23 of Set 11 | soubre
# Processing Record 24 of Set 11 | lazurne
# Processing Record 25 of Set 11 | sistranda
# Processing Record 26 of Set 11 | nambucca heads
# Processing Record 27 of Set 11 | kailua
# Processing Record 28 of Set 11 | brainerd
# Processing Record 29 of Set 11 | buala
# Processing Record 30 of Set 11 | corpus christi
# Processing Record 31 of Set 11 | grand forks
# Processing Record 32 of Set 11 | sorland
# Processing Record 33 of Set 11 | karratha
# Processing Record 34 of Set 11 | kirov
# Processing Record 35 of Set 11 | mehamn
# Processing Record 36 of Set 11 | erenhot
# Processing Record 37 of Set 11 | warrington
# Processing Record 38 of Set 11 | mezhdurechensk
# Processing Record 39 of Set 11 | sandur
# Processing Record 40 of Set 11 | okhotsk
# Processing Record 41 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 11 | alakurtti
# Processing Record 43 of Set 11 | pyay
# Processing Record 44 of Set 11 | sindor
# Processing Record 45 of Set 11 | finnsnes
# Processing Record 46 of Set 11 | rio grande
# Processing Record 47 of Set 11 | kasane
# Processing Record 48 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 11 | estacion coahuila
# Processing Record 50 of Set 11 | tete
# Processing Record 1 of Set 12 | dehloran
# Processing Record 2 of Set 12 | havre
# Processing Record 3 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 12 | soc trang
# Processing Record 5 of Set 12 | lamu
# Processing Record 6 of Set 12 | zabol
# Processing Record 7 of Set 12 | prerov
# Processing Record 8 of Set 12 | charlestown
# Processing Record 9 of Set 12 | saint-pierre
# Processing Record 10 of Set 12 | rockhampton
# Processing Record 11 of Set 12 | tome
# Processing Record 12 of Set 12 | miles city
# Processing Record 13 of Set 12 | odienne
# Processing Record 14 of Set 12 | alekseyevsk
# Processing Record 15 of Set 12 | namatanai
# Processing Record 16 of Set 12 | vila
# Processing Record 17 of Set 12 | oranjemund
# Processing Record 18 of Set 12 | hikone
# Processing Record 19 of Set 12 | nipawin
# Processing Record 20 of Set 12 | dale
# Processing Record 21 of Set 12 | teguldet
# Processing Record 22 of Set 12 | aksarka
# Processing Record 23 of Set 12 | leshukonskoye
# Processing Record 24 of Set 12 | port hedland
# Processing Record 25 of Set 12 | ceglie messapica
# Processing Record 26 of Set 12 | arman
# Processing Record 27 of Set 12 | basna
# Processing Record 28 of Set 12 | cabedelo
# Processing Record 29 of Set 12 | birigui
# Processing Record 30 of Set 12 | valleyview
# Processing Record 31 of Set 12 | yashan
# Processing Record 32 of Set 12 | vestmanna
# Processing Record 33 of Set 12 | rehoboth
# Processing Record 34 of Set 12 | narsaq
# Processing Record 35 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 36 of Set 12 | srednekolymsk
# Processing Record 37 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 12 | kulevcha
# Processing Record 39 of Set 12 | barra
# Processing Record 40 of Set 12 | turochak
# Processing Record 41 of Set 12 | pisco
# Processing Record 42 of Set 12 | kemijarvi
# Processing Record 43 of Set 12 | biri
# Processing Record 44 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 12 | viedma
# Processing Record 46 of Set 12 | port lincoln
# Processing Record 47 of Set 12 | kerema
# Processing Record 48 of Set 12 | geilo
# Processing Record 49 of Set 12 | xichang
# Processing Record 50 of Set 12 | asau
# Processing Record 1 of Set 13 | waingapu
# Processing Record 2 of Set 13 | nyaunglebin
# Processing Record 3 of Set 13 | avera
# Processing Record 4 of Set 13 | rochegda
# Processing Record 5 of Set 13 | huixtla
# Processing Record 6 of Set 13 | racine
# Processing Record 7 of Set 13 | tiarei
# Processing Record 8 of Set 13 | porto nacional
# Processing Record 9 of Set 13 | saskylakh
# Processing Record 10 of Set 13 | boali
# Processing Record 11 of Set 13 | puerto el triunfo
# Processing Record 12 of Set 13 | port-gentil
# Processing Record 13 of Set 13 | bismil
# Processing Record 14 of Set 13 | petropavlovka
# Processing Record 15 of Set 13 | fallon
# Processing Record 16 of Set 13 | pendencias
# Processing Record 17 of Set 13 | caravelas
# Processing Record 18 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 13 | burgeo
# Processing Record 20 of Set 13 | gurupa
# Processing Record 21 of Set 13 | kahului
# Processing Record 22 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 13 | puerto ayacucho
# Processing Record 24 of Set 13 | ust-tsilma
# Processing Record 25 of Set 13 | we
# City not found. Skipping...
# Processing Record 26 of Set 13 | sobolevo
# Processing Record 27 of Set 13 | bambanglipuro
# Processing Record 28 of Set 13 | kochinda
# Processing Record 29 of Set 13 | ranong
# Processing Record 30 of Set 13 | moyale
# Processing Record 31 of Set 13 | buin
# Processing Record 32 of Set 13 | dedougou
# Processing Record 33 of Set 13 | talakan
# Processing Record 34 of Set 13 | akhaldaba
# Processing Record 35 of Set 13 | piacabucu
# Processing Record 36 of Set 13 | black river
# Processing Record 37 of Set 13 | copiapo
# Processing Record 38 of Set 13 | veraval
# Processing Record 39 of Set 13 | malinovoye ozero
# Processing Record 40 of Set 13 | tonkino
# Processing Record 41 of Set 13 | capreol
# Processing Record 42 of Set 13 | mount gambier
# Processing Record 43 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 13 | merauke
# Processing Record 45 of Set 13 | nagapattinam
# Processing Record 46 of Set 13 | aginskoye
# Processing Record 47 of Set 13 | carbonia
# Processing Record 48 of Set 13 | moree
# Processing Record 49 of Set 13 | petric
# City not found. Skipping...
# Processing Record 50 of Set 13 | celestun
# Processing Record 1 of Set 14 | taonan
# Processing Record 2 of Set 14 | aquiraz
# Processing Record 3 of Set 14 | kamenskiy
# Processing Record 4 of Set 14 | brownsville
# Processing Record 5 of Set 14 | waitati
# Processing Record 6 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 7 of Set 14 | duz
# City not found. Skipping...
# Processing Record 8 of Set 14 | damphu
# Processing Record 9 of Set 14 | chapais
# Processing Record 10 of Set 14 | mrakovo
# Processing Record 11 of Set 14 | corinto
# Processing Record 12 of Set 14 | berlevag
# Processing Record 13 of Set 14 | kalabo
# Processing Record 14 of Set 14 | malinovskiy
# Processing Record 15 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 16 of Set 14 | partenit
# Processing Record 17 of Set 14 | mogadishu
# Processing Record 18 of Set 14 | kismayo
# Processing Record 19 of Set 14 | quang ngai
# Processing Record 20 of Set 14 | hunucma
# Processing Record 21 of Set 14 | chunskiy
# Processing Record 22 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record 23 of Set 14 | nemuro
# Processing Record 24 of Set 14 | changli
# Processing Record 25 of Set 14 | jeremie
# Processing Record 26 of Set 14 | changzhou
# Processing Record 27 of Set 14 | hvolsvollur
# Processing Record 28 of Set 14 | ballina
# Processing Record 29 of Set 14 | shelburne
# Processing Record 30 of Set 14 | yangambi
# Processing Record 31 of Set 14 | lagdo
# Processing Record 32 of Set 14 | mpika
# Processing Record 33 of Set 14 | knysna
# Processing Record 34 of Set 14 | pirgos
# Processing Record 35 of Set 14 | grajau
# Processing Record 36 of Set 14 | nichinan
# Processing Record 37 of Set 14 | benxi
# Processing Record 38 of Set 14 | muravlenko
# Processing Record 39 of Set 14 | mount isa
# Processing Record 40 of Set 14 | pinheiro machado
# Processing Record 41 of Set 14 | usinsk
# Processing Record 42 of Set 14 | corleone
# Processing Record 43 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 14 | george town
# Processing Record 45 of Set 14 | chumphon
# Processing Record 46 of Set 14 | hay river
# Processing Record 47 of Set 14 | kindu
# Processing Record 48 of Set 14 | yarkovo
# Processing Record 49 of Set 14 | wilmington
# Processing Record 50 of Set 14 | kijang
# Processing Record 1 of Set 15 | belmonte
# Processing Record 2 of Set 15 | kloulklubed
# Processing Record 3 of Set 15 | wismar
# Processing Record 4 of Set 15 | bosaso
# Processing Record 5 of Set 15 | along
# Processing Record 6 of Set 15 | makat
# Processing Record 7 of Set 15 | karasjok
# Processing Record 8 of Set 15 | udachnyy
# Processing Record 9 of Set 15 | whyalla
# Processing Record 10 of Set 15 | nukus
# Processing Record 11 of Set 15 | chhindwara
# Processing Record 12 of Set 15 | yungkang
# City not found. Skipping...
# Processing Record 13 of Set 15 | wareham
# Processing Record 14 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 15 | valparaiso
# Processing Record 16 of Set 15 | thabazimbi
# Processing Record 17 of Set 15 | inhambane
# Processing Record 18 of Set 15 | nizhniy kuranakh
# Processing Record 19 of Set 15 | rabo de peixe
# Processing Record 20 of Set 15 | maine-soroa
# Processing Record 21 of Set 15 | gat
# Processing Record 22 of Set 15 | bonanza
# Processing Record 23 of Set 15 | kinablangan
# Processing Record 24 of Set 15 | peruibe
# Processing Record 25 of Set 15 | sulangan
# Processing Record 26 of Set 15 | metro
# Processing Record 27 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 15 | gushikawa
# Processing Record 29 of Set 15 | harper
# Processing Record 30 of Set 15 | mildura
# Processing Record 31 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 15 | snasa
# Processing Record 33 of Set 15 | xingyi
# Processing Record 34 of Set 15 | bjerkvik
# Processing Record 35 of Set 15 | gbadolite
# Processing Record 36 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 37 of Set 15 | laurel
# Processing Record 38 of Set 15 | bereda
# Processing Record 39 of Set 15 | bac lieu
# Processing Record 40 of Set 15 | veseloyarsk
# Processing Record 41 of Set 15 | husavik
# Processing Record 42 of Set 15 | kashi
# Processing Record 43 of Set 15 | aksu
# Processing Record 44 of Set 15 | lufilufi
# Processing Record 45 of Set 15 | barcelos
# Processing Record 46 of Set 15 | arya
# Processing Record 47 of Set 15 | sirawai
# Processing Record 48 of Set 15 | orlik
# Processing Record 49 of Set 15 | novyy urengoy
# Processing Record 50 of Set 15 | laguna
# Processing Record 1 of Set 16 | tahoua
# Processing Record 2 of Set 16 | hirara
# Processing Record 3 of Set 16 | necochea
# Processing Record 4 of Set 16 | dubna
# Processing Record 5 of Set 16 | the valley
# Processing Record 6 of Set 16 | paamiut
# Processing Record 7 of Set 16 | karakendzha
# City not found. Skipping...
# Processing Record 8 of Set 16 | waterloo
# Processing Record 9 of Set 16 | mangai
# Processing Record 10 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 16 | launceston
# Processing Record 12 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 16 | ariguani
# Processing Record 14 of Set 16 | penukonda
# Processing Record 15 of Set 16 | samana
# Processing Record 16 of Set 16 | adamas
# Processing Record 17 of Set 16 | rawson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     42.91        61          20
# 1     Salihorsk  52.7876   27.5415     30.60        96         100
# 2    Rudnogorsk  57.2639  103.7519     25.00        94         100
# 3  Norman Wells  65.2820 -126.8329     12.24        44          20
# 4       Mataura -46.1927  168.8643     49.60        81          66
# 5    Bredasdorp -34.5322   20.0403     58.66        75           2
# 6       Rikitea -23.1203 -134.9692     78.66        68          43
# 7       Ushuaia -54.8000  -68.3000     37.06        87          40
# 8    Chokurdakh  70.6333  147.9167     -7.24        95          77
# 9    Kelvington  52.1667 -103.5343     36.16        83          99
#
#    Wind Speed Country                 Date
# 0       11.50      CL  2022-04-05 23:53:59
# 1        6.51      BY  2022-04-05 23:53:59
# 2        2.24      RU  2022-04-05 23:53:59
# 3        4.61      CA  2022-04-05 23:54:00
# 4       12.86      NZ  2022-04-05 23:54:00
# 5       13.09      ZA  2022-04-05 23:54:01
# 6       17.65      PF  2022-04-05 23:54:01
# 7       25.32      AR  2022-04-05 23:51:31
# 8        5.64      RU  2022-04-05 23:54:01
# 9       15.14      CA  2022-04-05 23:54:02
