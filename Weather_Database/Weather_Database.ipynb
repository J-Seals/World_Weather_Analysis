# %%
from citipy import citipy 
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7ea6b6fc43a70611a51955bf5b262681

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 584

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city_data = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | haines junction
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | manbij
# Processing Record 4 of Set 1 | hede
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | leh
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | zaysan
# Processing Record 12 of Set 1 | kavaratti
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | rio gallegos
# Processing Record 15 of Set 1 | aklavik
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | laguna
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | puerto escondido
# Processing Record 22 of Set 1 | waingapu
# Processing Record 23 of Set 1 | hodal
# Processing Record 24 of Set 1 | puerto colombia
# Processing Record 25 of Set 1 | poso
# Processing Record 26 of Set 1 | kutum
# Processing Record 27 of Set 1 | samarai
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | oyama
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | clyde river
# Processing Record 35 of Set 1 | kaa-khem
# Processing Record 36 of Set 1 | banda aceh
# Processing Record 37 of Set 1 | kalmunai
# Processing Record 38 of Set 1 | kalmar
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | esmeraldas
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | verkhnetulomskiy
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | ulagan
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | flinders
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | salalah
# Processing Record 49 of Set 1 | hovd
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | schwandorf
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | hualmay
# Processing Record 7 of Set 2 | souillac
# Processing Record 8 of Set 2 | serenje
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | dunedin
# Processing Record 12 of Set 2 | beisfjord
# Processing Record 13 of Set 2 | lata
# Processing Record 14 of Set 2 | wencheng
# Processing Record 15 of Set 2 | port lincoln
# Processing Record 16 of Set 2 | grindavik
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | broken hill
# Processing Record 20 of Set 2 | nicoya
# Processing Record 21 of Set 2 | soto la marina
# Processing Record 22 of Set 2 | salekhard
# Processing Record 23 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 2 | tuburan
# Processing Record 25 of Set 2 | tura
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | dong hoi
# Processing Record 30 of Set 2 | margate
# Processing Record 31 of Set 2 | tema
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | popondetta
# Processing Record 34 of Set 2 | sao joao da barra
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | pacific grove
# Processing Record 37 of Set 2 | yar-sale
# Processing Record 38 of Set 2 | tessalit
# Processing Record 39 of Set 2 | maraa
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | vagay
# Processing Record 42 of Set 2 | rio grande
# Processing Record 43 of Set 2 | sola
# Processing Record 44 of Set 2 | thompson
# Processing Record 45 of Set 2 | tuatapere
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | aginskoye
# Processing Record 48 of Set 2 | bo phloi
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | mobaye
# Processing Record 1 of Set 3 | guthrie
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | dinhata
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | waycross
# Processing Record 6 of Set 3 | tezu
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | jalu
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | constitucion
# Processing Record 11 of Set 3 | muros
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | chengde
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | pevek
# Processing Record 16 of Set 3 | ixtapa
# Processing Record 17 of Set 3 | kulhudhuffushi
# Processing Record 18 of Set 3 | bathsheba
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | half moon bay
# Processing Record 21 of Set 3 | tonj
# Processing Record 22 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 3 | venado tuerto
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | virginia beach
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | kilembe
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | tumut
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | santa marta
# Processing Record 32 of Set 3 | lukoyanov
# Processing Record 33 of Set 3 | katsuura
# Processing Record 34 of Set 3 | talnakh
# Processing Record 35 of Set 3 | vestmannaeyjar
# Processing Record 36 of Set 3 | hami
# Processing Record 37 of Set 3 | shimoda
# Processing Record 38 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 3 | palmer
# Processing Record 40 of Set 3 | baijiantan
# Processing Record 41 of Set 3 | gamba
# Processing Record 42 of Set 3 | olafsvik
# Processing Record 43 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 3 | abu samrah
# Processing Record 45 of Set 3 | jesup
# Processing Record 46 of Set 3 | mar del plata
# Processing Record 47 of Set 3 | mitzic
# Processing Record 48 of Set 3 | guerrero negro
# Processing Record 49 of Set 3 | adrar
# Processing Record 50 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 4 | porto velho
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | marsh harbour
# Processing Record 4 of Set 4 | saskylakh
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | oussouye
# Processing Record 7 of Set 4 | baykit
# Processing Record 8 of Set 4 | yuanping
# Processing Record 9 of Set 4 | aykhal
# Processing Record 10 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | qaqortoq
# Processing Record 13 of Set 4 | kiunga
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | san cristobal
# Processing Record 16 of Set 4 | port hardy
# Processing Record 17 of Set 4 | henties bay
# Processing Record 18 of Set 4 | la baneza
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | caravelas
# Processing Record 21 of Set 4 | benghazi
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | tilichiki
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | tela
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | kushima
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | visakhapatnam
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | sao gabriel da cachoeira
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | namatanai
# Processing Record 35 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | kahului
# Processing Record 39 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 4 | miyang
# Processing Record 41 of Set 4 | ponta delgada
# Processing Record 42 of Set 4 | turukhansk
# Processing Record 43 of Set 4 | birjand
# Processing Record 44 of Set 4 | kotelnikovo
# Processing Record 45 of Set 4 | polson
# Processing Record 46 of Set 4 | hithadhoo
# Processing Record 47 of Set 4 | magaria
# Processing Record 48 of Set 4 | boa vista
# Processing Record 49 of Set 4 | heiligenhafen
# Processing Record 50 of Set 4 | mahibadhoo
# Processing Record 1 of Set 5 | lokomotivnyy
# Processing Record 2 of Set 5 | paamiut
# Processing Record 3 of Set 5 | gubkinskiy
# Processing Record 4 of Set 5 | rocha
# Processing Record 5 of Set 5 | ransang
# Processing Record 6 of Set 5 | manakara
# Processing Record 7 of Set 5 | la macarena
# Processing Record 8 of Set 5 | vila velha
# Processing Record 9 of Set 5 | vilhena
# Processing Record 10 of Set 5 | golkoy
# Processing Record 11 of Set 5 | batagay
# Processing Record 12 of Set 5 | amapa
# Processing Record 13 of Set 5 | farim
# Processing Record 14 of Set 5 | comodoro rivadavia
# Processing Record 15 of Set 5 | walvis bay
# Processing Record 16 of Set 5 | uruguaiana
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | karaton
# Processing Record 19 of Set 5 | jonava
# Processing Record 20 of Set 5 | feijo
# Processing Record 21 of Set 5 | coihaique
# Processing Record 22 of Set 5 | alice springs
# Processing Record 23 of Set 5 | le pradet
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | bredasdorp
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | sinazongwe
# Processing Record 28 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 5 | tiksi
# Processing Record 30 of Set 5 | cherskiy
# Processing Record 31 of Set 5 | ulaangom
# Processing Record 32 of Set 5 | udachnyy
# Processing Record 33 of Set 5 | denpasar
# Processing Record 34 of Set 5 | la ronge
# Processing Record 35 of Set 5 | jumla
# Processing Record 36 of Set 5 | harper
# Processing Record 37 of Set 5 | keetmanshoop
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | nakhon phanom
# Processing Record 41 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 5 | sur
# Processing Record 43 of Set 5 | portland
# Processing Record 44 of Set 5 | bengkulu
# Processing Record 45 of Set 5 | bac lieu
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 5 | orangeburg
# Processing Record 49 of Set 5 | spasskoye
# Processing Record 50 of Set 5 | manjacaze
# Processing Record 1 of Set 6 | kurmanayevka
# Processing Record 2 of Set 6 | alofi
# Processing Record 3 of Set 6 | lavrentiya
# Processing Record 4 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 5 of Set 6 | terenga
# City not found. Skipping...
# Processing Record 6 of Set 6 | okhotsk
# Processing Record 7 of Set 6 | taseyevo
# Processing Record 8 of Set 6 | magnitka
# Processing Record 9 of Set 6 | sorland
# Processing Record 10 of Set 6 | nome
# Processing Record 11 of Set 6 | homer
# Processing Record 12 of Set 6 | ranau
# Processing Record 13 of Set 6 | messina
# Processing Record 14 of Set 6 | opuwo
# Processing Record 15 of Set 6 | deskati
# Processing Record 16 of Set 6 | heyang
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 6 | pisco
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | phuket
# Processing Record 22 of Set 6 | vila franca do campo
# Processing Record 23 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 6 | taft
# Processing Record 25 of Set 6 | quatre cocos
# Processing Record 26 of Set 6 | havoysund
# Processing Record 27 of Set 6 | birao
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | scarborough
# Processing Record 30 of Set 6 | soe
# Processing Record 31 of Set 6 | hofn
# Processing Record 32 of Set 6 | grand gaube
# Processing Record 33 of Set 6 | prince albert
# Processing Record 34 of Set 6 | yangjiang
# Processing Record 35 of Set 6 | myre
# Processing Record 36 of Set 6 | starkville
# Processing Record 37 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 6 | ponta do sol
# Processing Record 39 of Set 6 | nampula
# Processing Record 40 of Set 6 | saurimo
# Processing Record 41 of Set 6 | opobo
# City not found. Skipping...
# Processing Record 42 of Set 6 | leningradskiy
# Processing Record 43 of Set 6 | pietarsaari
# Processing Record 44 of Set 6 | lubao
# Processing Record 45 of Set 6 | chokurdakh
# Processing Record 46 of Set 6 | karratha
# Processing Record 47 of Set 6 | winnemucca
# Processing Record 48 of Set 6 | lillehammer
# Processing Record 49 of Set 6 | bulgan
# Processing Record 50 of Set 6 | batticaloa
# Processing Record 1 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 3 of Set 7 | vilyuysk
# Processing Record 4 of Set 7 | port elizabeth
# Processing Record 5 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 7 | jagatsinghapur
# Processing Record 7 of Set 7 | isangel
# Processing Record 8 of Set 7 | san andres
# Processing Record 9 of Set 7 | riberalta
# Processing Record 10 of Set 7 | korla
# Processing Record 11 of Set 7 | marzuq
# Processing Record 12 of Set 7 | oktyabrskoye
# Processing Record 13 of Set 7 | zhigansk
# Processing Record 14 of Set 7 | namibe
# Processing Record 15 of Set 7 | narsaq
# Processing Record 16 of Set 7 | taonan
# Processing Record 17 of Set 7 | elblag
# Processing Record 18 of Set 7 | nouadhibou
# Processing Record 19 of Set 7 | san policarpo
# Processing Record 20 of Set 7 | amboasary
# Processing Record 21 of Set 7 | pandan
# Processing Record 22 of Set 7 | sahaswan
# Processing Record 23 of Set 7 | cabo san lucas
# Processing Record 24 of Set 7 | alappuzha
# Processing Record 25 of Set 7 | porbandar
# Processing Record 26 of Set 7 | novyy urgal
# Processing Record 27 of Set 7 | pasighat
# Processing Record 28 of Set 7 | airai
# Processing Record 29 of Set 7 | saint george
# Processing Record 30 of Set 7 | kolokani
# Processing Record 31 of Set 7 | ugoofaaru
# Processing Record 32 of Set 7 | newport
# Processing Record 33 of Set 7 | shima
# Processing Record 34 of Set 7 | sioux lookout
# Processing Record 35 of Set 7 | lewiston
# Processing Record 36 of Set 7 | kloulklubed
# Processing Record 37 of Set 7 | mandalgovi
# Processing Record 38 of Set 7 | kitgum
# Processing Record 39 of Set 7 | cascais
# Processing Record 40 of Set 7 | eirunepe
# Processing Record 41 of Set 7 | mantua
# Processing Record 42 of Set 7 | payyannur
# Processing Record 43 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 7 | quzhou
# Processing Record 45 of Set 7 | dryden
# Processing Record 46 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 7 | tromso
# Processing Record 48 of Set 7 | shingu
# Processing Record 49 of Set 7 | xiaoshi
# Processing Record 50 of Set 7 | suntar
# Processing Record 1 of Set 8 | bahia blanca
# Processing Record 2 of Set 8 | woodward
# Processing Record 3 of Set 8 | lubu
# Processing Record 4 of Set 8 | nabire
# Processing Record 5 of Set 8 | roma
# Processing Record 6 of Set 8 | panjab
# Processing Record 7 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 8 | haukipudas
# Processing Record 9 of Set 8 | suraabad
# Processing Record 10 of Set 8 | ampanihy
# Processing Record 11 of Set 8 | axim
# Processing Record 12 of Set 8 | impfondo
# Processing Record 13 of Set 8 | longyearbyen
# Processing Record 14 of Set 8 | umm kaddadah
# Processing Record 15 of Set 8 | aflao
# Processing Record 16 of Set 8 | sawakin
# Processing Record 17 of Set 8 | lagoa
# Processing Record 18 of Set 8 | kargasok
# Processing Record 19 of Set 8 | te anau
# Processing Record 20 of Set 8 | magalia
# Processing Record 21 of Set 8 | dorgos
# Processing Record 22 of Set 8 | tall kayf
# Processing Record 23 of Set 8 | umba
# Processing Record 24 of Set 8 | feira de santana
# Processing Record 25 of Set 8 | sitio novo do tocantins
# Processing Record 26 of Set 8 | grande prairie
# Processing Record 27 of Set 8 | moshny
# Processing Record 28 of Set 8 | formosa
# Processing Record 29 of Set 8 | klaksvik
# Processing Record 30 of Set 8 | tuktoyaktuk
# Processing Record 31 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 8 | ciortesti
# Processing Record 33 of Set 8 | ruangwa
# Processing Record 34 of Set 8 | wanxian
# Processing Record 35 of Set 8 | ritchie
# Processing Record 36 of Set 8 | tabory
# Processing Record 37 of Set 8 | lompoc
# Processing Record 38 of Set 8 | soyo
# Processing Record 39 of Set 8 | vardo
# Processing Record 40 of Set 8 | plettenberg bay
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | havelock
# Processing Record 43 of Set 8 | mabaruma
# Processing Record 44 of Set 8 | kudahuvadhoo
# Processing Record 45 of Set 8 | the valley
# Processing Record 46 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 8 | kaeo
# Processing Record 48 of Set 8 | beira
# Processing Record 49 of Set 8 | brae
# Processing Record 50 of Set 8 | guane
# Processing Record 1 of Set 9 | xichang
# Processing Record 2 of Set 9 | saposoa
# Processing Record 3 of Set 9 | zalesovo
# Processing Record 4 of Set 9 | letlhakane
# Processing Record 5 of Set 9 | athabasca
# Processing Record 6 of Set 9 | la sarre
# Processing Record 7 of Set 9 | yulara
# Processing Record 8 of Set 9 | tsentralnyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | sungurlare
# Processing Record 10 of Set 9 | lakatoro
# Processing Record 11 of Set 9 | abu kamal
# Processing Record 12 of Set 9 | poronaysk
# Processing Record 13 of Set 9 | mogadishu
# Processing Record 14 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 9 | azle
# Processing Record 16 of Set 9 | srednekolymsk
# Processing Record 17 of Set 9 | nouakchott
# Processing Record 18 of Set 9 | wagar
# Processing Record 19 of Set 9 | yichun
# Processing Record 20 of Set 9 | mapiripan
# Processing Record 21 of Set 9 | monrovia
# Processing Record 22 of Set 9 | vicuna
# Processing Record 23 of Set 9 | taltal
# Processing Record 24 of Set 9 | roald
# Processing Record 25 of Set 9 | loutra
# Processing Record 26 of Set 9 | el porvenir
# Processing Record 27 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 9 | kankon
# Processing Record 29 of Set 9 | ilulissat
# Processing Record 30 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 31 of Set 9 | lashio
# Processing Record 32 of Set 9 | jining
# Processing Record 33 of Set 9 | faanui
# Processing Record 34 of Set 9 | pali
# Processing Record 35 of Set 9 | ulladulla
# Processing Record 36 of Set 9 | santa barbara
# Processing Record 37 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 9 | mitsamiouli
# Processing Record 39 of Set 9 | kjollefjord
# Processing Record 40 of Set 9 | verkhoshizhemye
# Processing Record 41 of Set 9 | ibra
# Processing Record 42 of Set 9 | sechura
# Processing Record 43 of Set 9 | khasan
# Processing Record 44 of Set 9 | kostomuksha
# Processing Record 45 of Set 9 | siocon
# Processing Record 46 of Set 9 | hervey bay
# Processing Record 47 of Set 9 | bow island
# Processing Record 48 of Set 9 | kahama
# Processing Record 49 of Set 9 | mayo
# Processing Record 50 of Set 9 | kieta
# Processing Record 1 of Set 10 | la orilla
# Processing Record 2 of Set 10 | borova
# Processing Record 3 of Set 10 | katherine
# Processing Record 4 of Set 10 | tangnan
# Processing Record 5 of Set 10 | cortez
# Processing Record 6 of Set 10 | meulaboh
# Processing Record 7 of Set 10 | kafanchan
# Processing Record 8 of Set 10 | shaowu
# Processing Record 9 of Set 10 | zhmerynka
# Processing Record 10 of Set 10 | srostki
# Processing Record 11 of Set 10 | kushiro
# Processing Record 12 of Set 10 | coruripe
# Processing Record 13 of Set 10 | kabo
# Processing Record 14 of Set 10 | diourbel
# Processing Record 15 of Set 10 | itigi
# Processing Record 16 of Set 10 | itoman
# Processing Record 17 of Set 10 | okato
# Processing Record 18 of Set 10 | bilma
# Processing Record 19 of Set 10 | nantucket
# Processing Record 20 of Set 10 | altay
# Processing Record 21 of Set 10 | fortuna
# Processing Record 22 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 10 | port blair
# Processing Record 24 of Set 10 | anchorage
# Processing Record 25 of Set 10 | chicama
# Processing Record 26 of Set 10 | vanderhoof
# Processing Record 27 of Set 10 | hay river
# Processing Record 28 of Set 10 | puerto del rosario
# Processing Record 29 of Set 10 | aripuana
# Processing Record 30 of Set 10 | krasnyy yar
# Processing Record 31 of Set 10 | acapulco
# Processing Record 32 of Set 10 | bembereke
# Processing Record 33 of Set 10 | belmonte
# Processing Record 34 of Set 10 | quezon
# Processing Record 35 of Set 10 | ilo
# Processing Record 36 of Set 10 | thinadhoo
# Processing Record 37 of Set 10 | naze
# Processing Record 38 of Set 10 | edinet
# Processing Record 39 of Set 10 | vysha
# Processing Record 40 of Set 10 | dmitriyevka
# Processing Record 41 of Set 10 | pangai
# Processing Record 42 of Set 10 | hilton head island
# Processing Record 43 of Set 10 | khani
# Processing Record 44 of Set 10 | atambua
# Processing Record 45 of Set 10 | pemangkat
# Processing Record 46 of Set 10 | tabuk
# Processing Record 47 of Set 10 | acari
# Processing Record 48 of Set 10 | bull savanna
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 50 of Set 10 | kichera
# Processing Record 1 of Set 11 | valleyview
# Processing Record 2 of Set 11 | talara
# Processing Record 3 of Set 11 | likasi
# Processing Record 4 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 11 | saint-joseph
# Processing Record 6 of Set 11 | sydney
# Processing Record 7 of Set 11 | perth
# Processing Record 8 of Set 11 | cam ranh
# Processing Record 9 of Set 11 | baruun-urt
# Processing Record 10 of Set 11 | saint anthony
# Processing Record 11 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 11 | sisimiut
# Processing Record 13 of Set 11 | honiara
# Processing Record 14 of Set 11 | bandarbeyla
# Processing Record 15 of Set 11 | hailar
# Processing Record 16 of Set 11 | kismayo
# Processing Record 17 of Set 11 | hargeysa
# Processing Record 18 of Set 11 | traralgon
# Processing Record 19 of Set 11 | esperance
# Processing Record 20 of Set 11 | douglas
# Processing Record 21 of Set 11 | batagay-alyta
# Processing Record 22 of Set 11 | cayenne
# Processing Record 23 of Set 11 | dongkan
# Processing Record 24 of Set 11 | flin flon
# Processing Record 25 of Set 11 | kununurra
# Processing Record 26 of Set 11 | galle
# Processing Record 27 of Set 11 | emerald
# Processing Record 28 of Set 11 | presidencia roque saenz pena
# Processing Record 29 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 11 | fort nelson
# Processing Record 31 of Set 11 | sangin
# Processing Record 32 of Set 11 | gurlan
# Processing Record 33 of Set 11 | springdale
# Processing Record 34 of Set 11 | bilibino
# Processing Record 35 of Set 11 | necochea
# Processing Record 36 of Set 11 | petauke
# Processing Record 37 of Set 11 | nalut
# Processing Record 38 of Set 11 | pahrump
# Processing Record 39 of Set 11 | naryan-mar
# Processing Record 40 of Set 11 | vao
# Processing Record 41 of Set 11 | southbridge
# Processing Record 42 of Set 11 | nemuro
# Processing Record 43 of Set 11 | goderich
# Processing Record 44 of Set 11 | springbok
# Processing Record 45 of Set 11 | nuuk
# Processing Record 46 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 11 | sawtell
# Processing Record 48 of Set 11 | panama city
# Processing Record 49 of Set 11 | xining
# Processing Record 50 of Set 11 | juba
# Processing Record 1 of Set 12 | urcos
# Processing Record 2 of Set 12 | whitehorse
# Processing Record 3 of Set 12 | korfez
# Processing Record 4 of Set 12 | riverton
# Processing Record 5 of Set 12 | komsomolskiy
# Processing Record 6 of Set 12 | dabat
# Processing Record 7 of Set 12 | okha
# Processing Record 8 of Set 12 | eyl
# Processing Record 9 of Set 12 | labuhan
# Processing Record 10 of Set 12 | adeje
# Processing Record 11 of Set 12 | kontagora
# Processing Record 12 of Set 12 | sambava
# Processing Record 13 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 12 | antofagasta
# Processing Record 15 of Set 12 | mobara
# Processing Record 16 of Set 12 | ambilobe
# Processing Record 17 of Set 12 | faya
# Processing Record 18 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 12 | ilebo
# Processing Record 20 of Set 12 | dondo
# Processing Record 21 of Set 12 | north bend
# Processing Record 22 of Set 12 | tateyama
# Processing Record 23 of Set 12 | trelew
# Processing Record 24 of Set 12 | asau
# Processing Record 25 of Set 12 | londonderry
# Processing Record 26 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 12 | beloha
# Processing Record 28 of Set 12 | puerto ayacucho
# Processing Record 29 of Set 12 | sangar
# Processing Record 30 of Set 12 | chifeng
# Processing Record 31 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 12 | prainha
# Processing Record 33 of Set 12 | mossendjo
# Processing Record 34 of Set 12 | port hedland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Haines Junction  60.7522 -137.5108     15.49        95          96
# 1          Ushuaia -54.8000  -68.3000     42.42        93         100
# 2           Manbij  36.5281   37.9549     68.81        33          10
# 3             Hede  33.7681  120.2517     40.86        58           6
# 4              Leh  34.1667   77.5833     32.76        56          86
# 5        Jamestown  42.0970  -79.2353     39.06        51           0
# 6           Castro -24.7911  -50.0119     64.40        82         100
# 7           Atuona  -9.8000 -139.0333     78.48        76           6
# 8           Zaysan  47.4667   84.8667     42.93        59          39
# 9        Kavaratti  10.5669   72.6420     83.37        70          51
#
#    Wind Speed Country                 Date
# 0        1.23      CA  2022-04-02 16:06:23
# 1        6.91      AR  2022-04-02 16:05:14
# 2        6.15      SY  2022-04-02 16:06:23
# 3        5.30      CN  2022-04-02 16:06:24
# 4        3.33      IN  2022-04-02 16:06:24
# 5        5.01      US  2022-04-02 16:05:11
# 6        8.86      BR  2022-04-02 16:06:25
# 7       14.85      PF  2022-04-02 16:06:25
# 8        2.35      KZ  2022-04-02 16:06:25
# 9        7.67      IN  2022-04-02 16:06:26
